# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
# Define your three custom colors
start_color = '#ffffff'  # White
mid_color = '#3395ea'    # Blue
end_color = '#0f2d46'    # Deep Blue

# %%
# O GLOBO special diverging colormaps
cmap = LinearSegmentedColormap.from_list('custom_diverging', [start_color, mid_color, end_color], N=256)

ogl_blue = LinearSegmentedColormap.from_list('custom_diverging', ['#ffffff', '#3395ea', '#0f2d46'], N=256)
ogl_red = LinearSegmentedColormap.from_list('custom_diverging', ['#ffffff', '#fc4f71', '#4c1822'], N=256)
ogl_yellow = LinearSegmentedColormap.from_list('custom_diverging', ['#ffffff', '#f1cf00', '#483e00'], N=256)

# %%
# Example data
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

# Plotting
plt.figure(figsize=(8, 6))
contourf = plt.contourf(X, Y, Z, cmap=ogl_yellow)
plt.colorbar(contourf)
plt.title('Custom Diverging Colormap')
plt.show()
